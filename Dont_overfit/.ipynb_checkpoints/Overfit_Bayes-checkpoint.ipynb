# %%
# Pcakges
import pymc3 as pm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import theano.tensor as tt
import theano
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
data_path = '/Users/smuch/Documents/coding/Study_PyMC3/Dont_overfit/'
#%%
data = pd.read_csv(data_path+'overfitting.csv')

# %%
data.head()
# Out:
#    case_id  train  Target_Practice  Target_Leaderboard  Target_Evaluate  \
# 0        1      1                0                   1                0
# 1        2      1                1                   0                1
# 2        3      1                0                   0                0
# 3        4      1                0                   1                1
# 4        5      1                0                   1                0
#
#    var_1  var_2  var_3  var_4  var_5   ...     var_191  var_192  var_193  \
# 0  0.660  0.106  0.434  0.387  0.903   ...       0.015    0.377    0.479
# 1  0.844  0.813  0.030  0.939  0.721   ...       0.112    0.048    0.088
# 2  0.560  0.567  0.568  0.434  0.414   ...       0.874    0.236    0.599
# 3  0.681  0.245  0.909  0.785  0.738   ...       0.219    0.691    0.261
# 4  0.846  0.431  0.805  0.237  0.465   ...       0.704    0.242    0.089
#
#    var_194  var_195  var_196  var_197  var_198  var_199  var_200
# ...

# %%
training_data = data[data.iloc[:, 1] == 1].iloc[:,5:]
testing_data = data[data.iloc[:, 1] == 0].iloc[:,5:]

training_labels = data[data.iloc[:, 1] == 1].iloc[:,2]
testing_labels = data[data.iloc[:, 1] == 0].iloc[:,2]

print ("training:", training_data.shape, training_labels.shape)
print ("testing: ", testing_data.shape, testing_labels.shape)
# Out:
# training: (250, 200) (250,)
# testing:  (19750, 200) (19750,)

# %%
plt.hist(np.array(training_data).flatten())
print (training_data.shape[0] * training_data.shape[1])
# Out:
# 50000

# %%
training_data = np.array(training_data)
testing_data = np.array(testing_data)

# %%
with pm.Model() as model:
    
# Select the para?
    to_include = pm.Bernoulli("to_include", 0.5, shape=(200))
# To give a diss for 200 vars 
    coef = pm.Uniform("coefs", 0, 1, shape=(200))   
    
    def Z(coef=coef, to_include=to_include, training_data=tt.as_tensor(training_data)):
        ym = tt.dot(to_include * training_data, coef)
        return ym - ym.mean()

    def T(z=Z):
        return 0.45 * (z/np.abs(z) + 1.1)
    
    Z = pm.Deterministic("Z",Z(coef=coef, to_include=to_include, training_data=tt.as_tensor(training_data)))
    T = pm.Deterministic("T",T(Z))
    
    obs = pm.Bernoulli("obs", T, observed=training_labels)
    trace = pm.sample(20000)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >BinaryGibbsMetropolis: [to_include]
# >NUTS: [coefs_interval__]
#   1%|          | 103/20500 [00:12<42:50,  7.94it/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/joblib/_parallel_backends.py", line 350, in __call__
#     return self.func(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/joblib/parallel.py", line 131, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/anaconda3/lib/python3.6/site-packages/joblib/parallel.py", line 131, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/anaconda3/lib/python3.6/site-packages/pymc3/sampling.py", line 554, in _sample
# ...

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c298246a0>,
# ...
#       dtype=object)

# %%
(np.round((trace["T"][-500:-300, :]).mean())== training_labels).mean()
# Out:
# 0.476

# %%
print (trace["T"][1:20, :].shape)
# Out:
# (19, 250)
