# %% [markdown]
# # 4 Inferences with Gaussians

# %%
import pymc3 as pm
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use('seaborn-darkgrid')

print("Load packages")
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Load packages

# %% [markdown]
# ## 4.1 Inferring a mean and standard deviation

# %%
# Data
x = np.array([1.1, 1.9, 2.3, 1.8])
n = len(x)

# %%
# Model
with pm.Model() as model1:
    # prior
    mu = pm.Normal('mu', mu=0, tau=.001)
    sigma = pm.Uniform('sigma', lower=0, upper=10)
    # observed
    xi = pm.Normal('xi',mu=mu, tau=1/(sigma**2), observed=x)
    # inference
    trace = pm.sample(1e3, cores=2)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma_interval__, mu]
# 100%|██████████| 1500/1500.0 [00:02<00:00, 709.70it/s]
# The number of effective samples is smaller than 25% for some parameters.

# %%
pm.traceplot(trace[50:]);

# %%
y = trace['mu']
x = trace['sigma']
sns.jointplot(x, y, kind='scatter', stat_func=None, alpha=.5);

print('The mu estimation is: %.3f' % y.mean())
print('The sigma estimation is: %.3f' % x.mean())
# Out:
# The mu estimation is: 1.761
# The sigma estimation is: 0.903

# %% [markdown]
# ## 4.2 The seven scientists

# %%
# data
x = np.array([-27.020, 3.570, 8.191, 9.898, 9.603, 9.945, 10.056])
n = len(x)

# %%
# Model
with pm.Model() as model2: 
    # prior
    mu = pm.Normal('mu', mu=0, tau=.001)
    lambda1 = pm.Gamma('lambda1', alpha=.01, beta=.01, shape=n)
    # sigma = pm.Deterministic('sigma',1 / sqrt(lambda1))
    # observed
    xi = pm.Normal('xi', mu=mu, tau=lambda1, observed=x)

    # inference
    trace2 = pm.sample(1000, cores=2)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [lambda1_log__, mu]
# 100%|██████████| 1500/1500 [00:03<00:00, 491.31it/s]
# The number of effective samples is smaller than 25% for some parameters.

# %%
pm.traceplot(trace2);
pm.summary(trace2)
# Out:
#                  mean         sd  mc_error       hpd_2.5    hpd_97.5  \
# mu           9.870619   0.223981  0.011765  9.488591e+00   10.222334
# lambda1__0   0.000723   0.001036  0.000028  9.748800e-11    0.002746
# lambda1__1   0.025471   0.034724  0.000906  2.633473e-10    0.094246
# lambda1__2   0.642617   5.621502  0.225300  5.486472e-11    1.455198
# lambda1__3  30.295725  46.139340  1.187538  9.266678e-04  122.778644
# lambda1__4  13.839295  31.269258  0.718235  5.959789e-06   56.846037
# lambda1__5  31.576344  51.905611  1.414366  3.499316e-06  132.517594
# lambda1__6  24.184164  39.718946  1.027432  9.136456e-07  102.511195
#
#                   n_eff      Rhat
# mu           230.530010  0.999527
# lambda1__0  1513.960602  1.000820
# lambda1__1  1491.322453  1.004890
# lambda1__2   411.034769  1.002084
# lambda1__3  1654.322978  1.003015
# lambda1__4  1675.366519  0.999533
# lambda1__5  1345.073695  0.999563
# lambda1__6  1679.077800  1.000457

# %% [markdown]
# ## 4.3 Repeated measurement of IQ

# %%
# Data
y = np.array([[90, 95, 100], [105, 110, 115], [150, 155, 160]])
ntest = 3
nsbj = 3
# Python > 2つのfloat値の比較 > sys.float_info.epsilonを使う
import sys
eps = sys.float_info.epsilon

# %%
# Model
with pm.Model() as model3:
    # mu_i ~ Uniform(0, 300)
    # notices the shape here need to be properly 
    # initualized to have the right repeated measure
    mui = pm.Uniform('mui', 0, 300, shape=(nsbj, 1))

    # sg ~ Uniform(0, 100)
    # sg = pm.Uniform('sg', .0, 100)
    
    # It is more stable to use a Gamma prior
    lambda1 = pm.Gamma('lambda1', alpha=.01, beta=.01)
    sg = pm.Deterministic('sg',1 / np.sqrt(lambda1))
    
    # y ~ Normal(mu_i, sg)
    yd = pm.Normal('y', mu=mui, sd=sg, observed=y)
    
    trace3 = pm.sample(1000, cores=2)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [lambda1_log__, mui_interval__]
# 100%|██████████| 1500/1500 [00:02<00:00, 520.45it/s]

# %%
#3 Plot
pm.traceplot(trace3);
pm.summary(trace3)
# Out:
#                 mean        sd  mc_error     hpd_2.5    hpd_97.5        n_eff  \
# mui__0_0   94.864699  3.601005  0.086512   87.847830  101.873696  1575.725038
# mui__1_0  110.022607  3.656277  0.088686  103.586112  118.132817  1676.572993
# mui__2_0  155.079175  3.644203  0.101834  147.958368  162.326998  1328.775638
# lambda1     0.038441  0.022307  0.000734    0.006095    0.083649   806.415751
# sg          5.849596  1.986983  0.071558    3.012866    9.719786   623.955348
#
#               Rhat
# mui__0_0  0.999534
# mui__1_0  0.999515
# mui__2_0  0.999676
# lambda1   1.003193
# sg        1.007100
